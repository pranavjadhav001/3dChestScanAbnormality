# %%
from PIL import Image #for reading a image
import numpy as np
import glob#access all .tiff files
import cv2
import scipy.ndimage
from mpl_toolkits import mplot3d
import matplotlib.pyplot as plt
from skimage import measure, morphology
from mpl_toolkits.mplot3d.art3d import Poly3DCollection
import math
import itertools
import os
import random

# %% [raw]
# Lets see how our chest ct scan data looks like

# %%
files = glob.glob(r'F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260/*.tiff')

# %%
image = []
for i in files:
    print(i)
    image.append(np.array(Image.open(i)))
image = np.array(image)
# Out:
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\0.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\1.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\10.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\100.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\101.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\102.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\103.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\104.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\105.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\106.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\107.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\108.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\109.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\11.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\110.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\111.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\112.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\113.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\114.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\115.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\116.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\117.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\118.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\119.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\12.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\120.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\121.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\122.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\123.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\124.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\125.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\126.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\127.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\128.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\129.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\13.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\130.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\131.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\132.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\133.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\134.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\135.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\136.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\137.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\138.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\139.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\14.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\140.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\141.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\142.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\143.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\144.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\145.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\146.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\147.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\148.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\149.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\15.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\150.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\151.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\152.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\153.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\154.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\155.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\156.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\157.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\158.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\159.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\16.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\160.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\161.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\162.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\163.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\164.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\165.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\166.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\167.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\168.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\169.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\17.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\170.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\171.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\172.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\173.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\174.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\175.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\176.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\177.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\178.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\179.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\18.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\180.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\181.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\182.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\183.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\184.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\185.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\186.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\187.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\188.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\189.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\19.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\190.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\191.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\192.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\193.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\194.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\195.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\196.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\197.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\198.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\199.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\2.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\20.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\200.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\201.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\202.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\203.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\204.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\205.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\206.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\207.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\208.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\209.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\21.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\210.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\211.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\212.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\213.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\214.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\215.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\216.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\217.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\218.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\219.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\22.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\220.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\221.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\222.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\223.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\224.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\225.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\226.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\227.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\228.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\229.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\23.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\230.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\231.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\232.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\233.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\234.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\235.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\236.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\237.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\238.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\239.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\24.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\240.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\241.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\242.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\243.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\244.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\245.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\246.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\247.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\248.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\249.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\25.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\250.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\251.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\252.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\253.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\254.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\255.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\256.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\257.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\258.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\259.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\26.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\260.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\261.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\262.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\263.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\264.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\265.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\266.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\267.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\268.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\269.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\27.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\270.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\271.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\272.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\273.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\274.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\275.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\276.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\277.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\278.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\279.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\28.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\280.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\281.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\282.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\283.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\284.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\285.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\286.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\287.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\288.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\289.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\29.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\290.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\291.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\292.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\293.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\294.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\295.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\296.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\297.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\298.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\299.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\3.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\30.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\300.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\301.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\31.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\32.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\33.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\34.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\35.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\36.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\37.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\38.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\39.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\4.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\40.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\41.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\42.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\43.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\44.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\45.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\46.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\47.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\48.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\49.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\5.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\50.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\51.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\52.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\53.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\54.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\55.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\56.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\57.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\58.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\59.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\6.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\60.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\61.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\62.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\63.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\64.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\65.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\66.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\67.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\68.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\69.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\7.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\70.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\71.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\72.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\73.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\74.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\75.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\76.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\77.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\78.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\79.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\8.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\80.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\81.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\82.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\83.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\84.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\85.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\86.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\87.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\88.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\89.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\9.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\90.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\91.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\92.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\93.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\94.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\95.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\96.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\97.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\98.tiff
# F:/notes/sample_dataset_for_testing/fullsampledata/subset0mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260\99.tiff

# %%
image.shape
# Out:
# (302, 512, 512)

# %%
IMG_PX_SIZE = 150
def image_show(image):
    fig = plt.figure()
    for num,each_slice in enumerate(image):
        y = fig.add_subplot(3,4,num+1)
        new_img = cv2.resize(each_slice,(IMG_PX_SIZE,IMG_PX_SIZE))
        y.imshow(new_img)
    plt.show()

# %% [raw]
# lets see the ct scan slices of a person just 12.

# %%
image_show(image[:12])

# %%
#Function that gives a list of a patient's ct scan slices
def directory_name():
    path = r'F:/notes/sample_dataset_for_testing/fullsampledata'
    paths = []
    for i in os.listdir(path):
        new_path = os.path.join(path,i)
        
        for j in os.listdir(new_path):
            final_path = os.path.join(new_path,j)
            paths.append(final_path)
        
    return paths

# %%
def alloperations(pathfile):
    #gives us the x,y,z coordinates of our mask_label
    def coordinates(a):
        list1 = []
        list2 = []
        X=[]
        Y=[]
        Z=[]
        B=a.reshape(a.shape[0]*a.shape[1]*a.shape[2],1)
        #print(B.shape)
        C=list(itertools.product(range(a.shape[0]),range(a.shape[1]),range(a.shape[2])))
        for i,n in enumerate(B):
            if n != 0:
                #print(n)
                list1.append(i)
        for j in list1:
            list2.append(C[j])
        for j in range(len(list2)):
            X.append(list2[j][0])
            Y.append(list2[j][1])
            Z.append(list2[j][2])
        return X,Y,Z
    #gives us array of only input image slices
    def image_label(path):
        files = glob.glob(os.path.join(path,'*.tiff'))
        image = []
        for i in files:
            if i.split('_')[-1] != 'mask.tiff':
                img = np.array(Image.open(i))
                img = cv2.resize(img,(200,200))
                image.append(img)
        image = np.array(image)
        return image

    #gives us array of mask_labels
    def make_label(path,image):
        mask_files= glob.glob(os.path.join(path,'*_mask.tiff'))
        dicti = {}
        for i in mask_files:
            dicti[i.split('\\')[-1].split('_')[0]] = i
        labels = []
        #print(len(files))
        for i in range(image.shape[0]):
            if str(i) in dicti:
                img = Image.open(dicti[str(i)])
                labels.append(cv2.resize(np.array(img),(200,200)))
            else:
                img = Image.open(r'F:/notes/sample_dataset_for_testing/fullsampledata/subset2mask/1.3.6.1.4.1.14519.5.2.1.6279.6001.109002525524522225658609808059/0.tiff')
                labels.append(cv2.resize(np.array(img),(200,200)))
        labels = np.array(labels)
        return labels          

    image = image_label(pathfile)
    label = make_label(pathfile,image)
    
    #helps us visualise where the abnormalities lie in the ct scan 
    def plot_3d(image,label,threshold=500):
        if image.shape == label.shape:
        # Position the scan upright, 
        # so the head of the patient would be at the top facing the camera
            p = image.transpose(2,1,0)
            label = label.transpose(2,1,0)
            xdata,ydata,zdata =coordinates(label)   
            verts, faces,normal,values = measure.marching_cubes_lewiner(p,threshold)

            fig = plt.figure(figsize=(10, 10))
            ax = fig.add_subplot(111, projection='3d')

            # Fancy indexing: `verts[faces]` to generate a collection of triangles
            mesh = Poly3DCollection(verts[faces], alpha=0.70)
            face_color = [0.15, 0.15, 0.45]
            mesh.set_facecolor(face_color)
            ax.add_collection3d(mesh)
            ax.scatter(xdata, ydata, zdata,c='r',marker='o')
            ax.set_xlim(0, p.shape[0])
            ax.set_ylim(0, p.shape[1])
            ax.set_zlim(0, p.shape[2])

            plt.show ()
        else:
            print('pls chck')
      
    plot_3d(image,label) 
    #uncomment this if u want to see 3d view
    return image,label

# %%
paths = directory_name()
paths[1]
# Out:
# 'F:/notes/sample_dataset_for_testing/fullsampledata\\subset1mask\\1.3.6.1.4.1.14519.5.2.1.6279.6001.108197895896446896160048741492'

# %%
image_batch,data_batch = alloperations(paths[1])# lets see for patient1

# %% [raw]
# As you can the 3d schematic of lung and red dot shows abnormalities.The dimension has been resized from 512*512 to 200*200.

# %%
#making chunks because 300 slices is way too many so averaging them to 20 slices per patient
def chunks(l, n):
    for i in range(0, len(l), n):
        yield l[i:i + n]

def mean(l):
    return sum(l) / len(l)

def make_chunks(image):
    HM_SLICES = 20
    chunk_sizes = math.ceil(len(image)/HM_SLICES)
    new_slices = []
    for slice_chunk in chunks(image,chunk_sizes):
        slice_chunk = list(map(mean, zip(*slice_chunk)))
        new_slices.append(np.array(slice_chunk))
    
    if len(new_slices) == HM_SLICES-1:
        new_slices.append(new_slices[-1])

    if len(new_slices) == HM_SLICES-2:
        new_slices.append(new_slices[-1])
        new_slices.append(new_slices[-1])

    if len(new_slices) == HM_SLICES+2:
        new_val = list(map(mean, zip(*[new_slices[HM_SLICES-1],new_slices[HM_SLICES],])))
        del new_slices[HM_SLICES]
        new_slices[HM_SLICES-1] = new_val
        
    if len(new_slices) == HM_SLICES+1:
        new_val = list(map(mean, zip(*[new_slices[HM_SLICES-1],new_slices[HM_SLICES],])))
        del new_slices[HM_SLICES]
        new_slices[HM_SLICES-1] = new_val

    new_slices = np.array(new_slices)
    return new_slices

# %%
#gives us the final image and label batch for our model
def final_labels_images():
    paths = directory_name()
    data = []
    label_data = []
    for i in range(len(paths)):
        image,label = alloperations(paths[i])
        image = make_chunks(image)
        label = make_chunks(label)
        data.append(image)
        label_data.append(label)
    data= np.array(data).reshape(10,20,200,200,1)
    label_data= np.array(label_data).reshape(10,20,200,200,1)
    return  data,label_data

# %%
image_batch,data_batch = final_labels_images()

# %%
image_batch.shape,data_batch.shape
# Out:
# ((10, 20, 200, 200, 1), (10, 20, 200, 200, 1))

# %%
Basically what we want is we feed our ct scan slices of a patient as input and want the output as 3d mask .Incase of no abnormalities , it gives us empty mask .
For this problem , I have chosen 3d Unet model.
Well autoencoder can also work but unet works better for medical imaging because of its skip connections.

# %%
from keras.layers import ConvLSTM2D, Bidirectional, BatchNormalization, Conv3D, Cropping3D, ZeroPadding3D, Activation, Input
from keras.layers import MaxPooling3D, UpSampling3D, Deconvolution3D, concatenate
from keras.models import Model

# %%
in_layer = Input((20, 200, 200, 1))
#bn = BatchNormalization()(in_layer)
cn1 = Conv3D(8, 
             kernel_size = (1, 5, 5), 
             padding = 'same',
             activation = 'relu')(in_layer)
cn2 = Conv3D(8, 
             kernel_size = (3, 3, 3),
             padding = 'same',
             activation = 'linear')(cn1)
bn2 = Activation('relu')(cn2)

dn1 = MaxPooling3D((2, 2, 2))(bn2)
cn3 = Conv3D(16, 
             kernel_size = (3, 3, 3),
             padding = 'same',
             activation = 'linear')(dn1)
bn3 = Activation('relu')(cn3)
dn2 = MaxPooling3D((1, 2, 2))(bn3)
cn4 = Conv3D(32, 
             kernel_size = (3, 3, 3),
             padding = 'same',
             activation = 'linear')(dn2)
bn4 = Activation('relu')(cn4)

up1 = Deconvolution3D(16, 
                      kernel_size = (3, 3, 3),
                      strides = (1, 2, 2),
                     padding = 'same')(bn4)

cat1 = concatenate([up1, bn3])

up2 = Deconvolution3D(8, 
                      kernel_size = (3, 3, 3),
                      strides = (2, 2, 2),
                     padding = 'same')(cat1)

pre_out = concatenate([up2, bn2])

pre_out = Conv3D(1, 
             kernel_size = (1, 1, 1), 
             padding = 'same',
             activation = 'sigmoid')(pre_out)
pre_out = Cropping3D((1, 2, 2))(pre_out) # avoid skewing boundaries
out = ZeroPadding3D((1, 2, 2))(pre_out)
sim_model = Model(inputs = [in_layer], outputs = [out])
sim_model.compile(optimizer='adam', loss='binary_crossentropy')

sim_model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 20, 200, 200, 0
# __________________________________________________________________________________________________
# conv3d_6 (Conv3D)               (None, 20, 200, 200, 208         input_2[0][0]
# __________________________________________________________________________________________________
# conv3d_7 (Conv3D)               (None, 20, 200, 200, 1736        conv3d_6[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 20, 200, 200, 0           conv3d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_3 (MaxPooling3D)  (None, 10, 100, 100, 0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv3d_8 (Conv3D)               (None, 10, 100, 100, 3472        max_pooling3d_3[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 10, 100, 100, 0           conv3d_8[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_4 (MaxPooling3D)  (None, 10, 50, 50, 1 0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv3d_9 (Conv3D)               (None, 10, 50, 50, 3 13856       max_pooling3d_4[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 10, 50, 50, 3 0           conv3d_9[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_3 (Conv3DTrans (None, 10, 100, 100, 13840       activation_6[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 10, 100, 100, 0           conv3d_transpose_3[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_4 (Conv3DTrans (None, 20, 200, 200, 6920        concatenate_3[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 20, 200, 200, 0           conv3d_transpose_4[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# conv3d_10 (Conv3D)              (None, 20, 200, 200, 17          concatenate_4[0][0]
# __________________________________________________________________________________________________
# cropping3d_2 (Cropping3D)       (None, 18, 196, 196, 0           conv3d_10[0][0]
# __________________________________________________________________________________________________
# zero_padding3d_2 (ZeroPadding3D (None, 20, 200, 200, 0           cropping3d_2[0][0]
# ==================================================================================================
# Total params: 40,049
# Trainable params: 40,049
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
results = sim_model.fit(image_batch,data_batch,epochs=5,batch_size=2)
# Out:
# Epoch 1/5
# 10/10 [==============================] - 8s 815ms/step - loss: 0.9879
# Epoch 2/5
# 10/10 [==============================] - 5s 472ms/step - loss: 0.0492
# Epoch 3/5
# 10/10 [==============================] - 5s 472ms/step - loss: 0.0449
# Epoch 4/5
# 10/10 [==============================] - 5s 472ms/step - loss: 0.0449
# Epoch 5/5
# 10/10 [==============================] - 5s 472ms/step - loss: 0.0449
